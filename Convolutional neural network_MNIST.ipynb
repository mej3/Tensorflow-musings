# %% [markdown]
# Reference:
# https://github.com/aymericdamien/TensorFlow-Examples/blob/master/notebooks/3_NeuralNetworks/convolutional_network.ipynb

# %% [markdown]
# ### Convolutional Neural Network on MNIST

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ###### Hyperparameters

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %% [markdown]
# ###### Create model and optimiser

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')#stride=1 for width and height
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')#k refers to the height and width of tensor which is 2 as usual

# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 22671.222656, Training Accuracy= 0.32812
# Iter 2560, Minibatch Loss= 9497.189453, Training Accuracy= 0.53906
# Iter 3840, Minibatch Loss= 6235.269531, Training Accuracy= 0.68750
# Iter 5120, Minibatch Loss= 6491.862793, Training Accuracy= 0.71875
# Iter 6400, Minibatch Loss= 4444.564453, Training Accuracy= 0.78906
# Iter 7680, Minibatch Loss= 4133.686035, Training Accuracy= 0.80469
# Iter 8960, Minibatch Loss= 2861.368896, Training Accuracy= 0.85156
# Iter 10240, Minibatch Loss= 2042.313354, Training Accuracy= 0.86719
# Iter 11520, Minibatch Loss= 3696.626221, Training Accuracy= 0.85156
# Iter 12800, Minibatch Loss= 2734.390137, Training Accuracy= 0.87500
# Iter 14080, Minibatch Loss= 3350.342285, Training Accuracy= 0.90625
# Iter 15360, Minibatch Loss= 2416.813477, Training Accuracy= 0.87500
# Iter 16640, Minibatch Loss= 2064.067871, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 1823.918579, Training Accuracy= 0.92188
# Iter 19200, Minibatch Loss= 1076.703857, Training Accuracy= 0.92188
# Iter 20480, Minibatch Loss= 1603.811890, Training Accuracy= 0.90625
# Iter 21760, Minibatch Loss= 2555.409912, Training Accuracy= 0.88281
# Iter 23040, Minibatch Loss= 1646.819336, Training Accuracy= 0.88281
# Iter 24320, Minibatch Loss= 1097.194214, Training Accuracy= 0.92969
# Iter 25600, Minibatch Loss= 495.521667, Training Accuracy= 0.96094
# Iter 26880, Minibatch Loss= 1467.260132, Training Accuracy= 0.90625
# Iter 28160, Minibatch Loss= 1118.791138, Training Accuracy= 0.94531
# Iter 29440, Minibatch Loss= 1180.421631, Training Accuracy= 0.90625
# Iter 30720, Minibatch Loss= 99.653351, Training Accuracy= 0.98438
# Iter 32000, Minibatch Loss= 1798.305664, Training Accuracy= 0.89844
# Iter 33280, Minibatch Loss= 1465.915283, Training Accuracy= 0.89062
# Iter 34560, Minibatch Loss= 1221.555176, Training Accuracy= 0.94531
# Iter 35840, Minibatch Loss= 731.464478, Training Accuracy= 0.96094
# Iter 37120, Minibatch Loss= 1742.757080, Training Accuracy= 0.92188
# Iter 38400, Minibatch Loss= 1739.255249, Training Accuracy= 0.89062
# Iter 39680, Minibatch Loss= 585.378052, Training Accuracy= 0.95312
# Iter 40960, Minibatch Loss= 614.266541, Training Accuracy= 0.96094
# Iter 42240, Minibatch Loss= 341.812439, Training Accuracy= 0.96094
# Iter 43520, Minibatch Loss= 854.485596, Training Accuracy= 0.91406
# Iter 44800, Minibatch Loss= 108.350288, Training Accuracy= 0.98438
# Iter 46080, Minibatch Loss= 505.578033, Training Accuracy= 0.95312
# Iter 47360, Minibatch Loss= 526.963745, Training Accuracy= 0.95312
# Iter 48640, Minibatch Loss= 296.831390, Training Accuracy= 0.95312
# Iter 49920, Minibatch Loss= 2016.939453, Training Accuracy= 0.89844
# Iter 51200, Minibatch Loss= 525.911987, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 1750.780029, Training Accuracy= 0.91406
# Iter 53760, Minibatch Loss= 331.151367, Training Accuracy= 0.97656
# Iter 55040, Minibatch Loss= 684.199097, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 603.610352, Training Accuracy= 0.93750
# Iter 57600, Minibatch Loss= 722.156738, Training Accuracy= 0.92969
# Iter 58880, Minibatch Loss= 566.071960, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 30.378601, Training Accuracy= 0.99219
# Iter 61440, Minibatch Loss= 280.462402, Training Accuracy= 0.97656
# Iter 62720, Minibatch Loss= 388.742859, Training Accuracy= 0.97656
# Iter 64000, Minibatch Loss= 646.647766, Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 542.529297, Training Accuracy= 0.94531
# Iter 66560, Minibatch Loss= 151.464493, Training Accuracy= 0.96875
# Iter 67840, Minibatch Loss= 222.590759, Training Accuracy= 0.96094
# Iter 69120, Minibatch Loss= 321.923920, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 297.722412, Training Accuracy= 0.95312
# Iter 71680, Minibatch Loss= 337.311890, Training Accuracy= 0.96094
# Iter 72960, Minibatch Loss= 434.675323, Training Accuracy= 0.94531
# Iter 74240, Minibatch Loss= 423.719910, Training Accuracy= 0.98438
# Iter 75520, Minibatch Loss= 384.725159, Training Accuracy= 0.96875
# Iter 76800, Minibatch Loss= 779.358765, Training Accuracy= 0.96094
# Iter 78080, Minibatch Loss= 647.642700, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 327.560120, Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 258.038300, Training Accuracy= 0.97656
# Iter 81920, Minibatch Loss= 146.989197, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 484.571045, Training Accuracy= 0.97656
# Iter 84480, Minibatch Loss= 416.019226, Training Accuracy= 0.95312
# Iter 85760, Minibatch Loss= 466.816101, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 287.196716, Training Accuracy= 0.96875
# Iter 88320, Minibatch Loss= 717.724243, Training Accuracy= 0.94531
# Iter 89600, Minibatch Loss= 84.355827, Training Accuracy= 0.98438
# Iter 90880, Minibatch Loss= 848.096069, Training Accuracy= 0.93750
# Iter 92160, Minibatch Loss= 105.279411, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 482.841309, Training Accuracy= 0.97656
# Iter 94720, Minibatch Loss= 41.153046, Training Accuracy= 0.99219
# Iter 96000, Minibatch Loss= 328.436523, Training Accuracy= 0.96875
# Iter 97280, Minibatch Loss= 396.226929, Training Accuracy= 0.96094
# Iter 98560, Minibatch Loss= 424.390533, Training Accuracy= 0.94531
# Iter 99840, Minibatch Loss= 215.016388, Training Accuracy= 0.98438
# Iter 101120, Minibatch Loss= 278.287140, Training Accuracy= 0.98438
# Iter 102400, Minibatch Loss= 340.204926, Training Accuracy= 0.96094
# Iter 103680, Minibatch Loss= 290.052521, Training Accuracy= 0.96875
# Iter 104960, Minibatch Loss= 358.792236, Training Accuracy= 0.95312
# Iter 106240, Minibatch Loss= 950.337402, Training Accuracy= 0.92188
# Iter 107520, Minibatch Loss= 350.299133, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 372.214966, Training Accuracy= 0.96875
# Iter 110080, Minibatch Loss= 68.206413, Training Accuracy= 0.97656
# Iter 111360, Minibatch Loss= 276.523071, Training Accuracy= 0.95312
# Iter 112640, Minibatch Loss= 132.718384, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 167.313690, Training Accuracy= 0.99219
# Iter 115200, Minibatch Loss= 220.750397, Training Accuracy= 0.96094
# Iter 116480, Minibatch Loss= 217.386597, Training Accuracy= 0.95312
# Iter 117760, Minibatch Loss= 416.282745, Training Accuracy= 0.97656
# Iter 119040, Minibatch Loss= 164.147705, Training Accuracy= 0.96094
# Iter 120320, Minibatch Loss= 365.455139, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 373.089355, Training Accuracy= 0.95312
# Iter 122880, Minibatch Loss= 99.854233, Training Accuracy= 0.98438
# Iter 124160, Minibatch Loss= 244.415833, Training Accuracy= 0.98438
# Iter 125440, Minibatch Loss= 176.738403, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 99.226372, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 164.875458, Training Accuracy= 0.98438
# Iter 129280, Minibatch Loss= 193.032867, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 56.468178, Training Accuracy= 0.99219
# Iter 131840, Minibatch Loss= 85.916801, Training Accuracy= 0.98438
# Iter 133120, Minibatch Loss= 55.913177, Training Accuracy= 0.99219
# Iter 134400, Minibatch Loss= 157.902679, Training Accuracy= 0.96094
# Iter 135680, Minibatch Loss= 72.215073, Training Accuracy= 0.98438
# Iter 136960, Minibatch Loss= 280.607574, Training Accuracy= 0.96875
# Iter 138240, Minibatch Loss= 322.452026, Training Accuracy= 0.99219
# Iter 139520, Minibatch Loss= 1.667297, Training Accuracy= 0.99219
# Iter 140800, Minibatch Loss= 275.426697, Training Accuracy= 0.94531
# Iter 142080, Minibatch Loss= 336.600922, Training Accuracy= 0.98438
# Iter 143360, Minibatch Loss= 46.446976, Training Accuracy= 0.99219
# Iter 144640, Minibatch Loss= 237.647018, Training Accuracy= 0.98438
# Iter 145920, Minibatch Loss= 243.759583, Training Accuracy= 0.96094
# Iter 147200, Minibatch Loss= 721.109131, Training Accuracy= 0.94531
# Iter 148480, Minibatch Loss= 273.935089, Training Accuracy= 0.96875
# Iter 149760, Minibatch Loss= 273.147919, Training Accuracy= 0.94531
# Iter 151040, Minibatch Loss= 169.218964, Training Accuracy= 0.96875
# Iter 152320, Minibatch Loss= 408.565399, Training Accuracy= 0.96875
# Iter 153600, Minibatch Loss= 438.000488, Training Accuracy= 0.96094
# Iter 154880, Minibatch Loss= 160.393631, Training Accuracy= 0.98438
# Iter 156160, Minibatch Loss= 198.267151, Training Accuracy= 0.96875
# Iter 157440, Minibatch Loss= 613.138245, Training Accuracy= 0.96094
# Iter 158720, Minibatch Loss= 122.514259, Training Accuracy= 0.98438
# Iter 160000, Minibatch Loss= 425.142609, Training Accuracy= 0.94531
# Iter 161280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 162560, Minibatch Loss= 267.341675, Training Accuracy= 0.93750
# Iter 163840, Minibatch Loss= 294.878021, Training Accuracy= 0.96875
# Iter 165120, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 166400, Minibatch Loss= 352.423706, Training Accuracy= 0.95312
# Iter 167680, Minibatch Loss= 314.137390, Training Accuracy= 0.97656
# Iter 168960, Minibatch Loss= 121.879906, Training Accuracy= 0.97656
# Iter 170240, Minibatch Loss= 52.034332, Training Accuracy= 0.98438
# Iter 171520, Minibatch Loss= 59.555984, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 107.947083, Training Accuracy= 0.98438
# Iter 174080, Minibatch Loss= 166.552979, Training Accuracy= 0.97656
# Iter 175360, Minibatch Loss= 110.666718, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 95.096802, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 24.117264, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 217.080414, Training Accuracy= 0.97656
# Iter 180480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 181760, Minibatch Loss= 311.394836, Training Accuracy= 0.98438
# Iter 183040, Minibatch Loss= 152.883499, Training Accuracy= 0.97656
# Iter 184320, Minibatch Loss= 12.190720, Training Accuracy= 0.99219
# Iter 185600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 186880, Minibatch Loss= 180.335968, Training Accuracy= 0.99219
# Iter 188160, Minibatch Loss= 210.544739, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 222.072952, Training Accuracy= 0.98438
# Iter 190720, Minibatch Loss= 123.759239, Training Accuracy= 0.95312
# Iter 192000, Minibatch Loss= 33.762604, Training Accuracy= 0.98438
# Iter 193280, Minibatch Loss= 8.899597, Training Accuracy= 0.99219
# Iter 194560, Minibatch Loss= 44.002434, Training Accuracy= 0.96875
# Iter 195840, Minibatch Loss= 264.067017, Training Accuracy= 0.96875
# Iter 197120, Minibatch Loss= 93.795639, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 268.411255, Training Accuracy= 0.93750
# Iter 199680, Minibatch Loss= 74.891884, Training Accuracy= 0.96875
# Optimization Finished!
# Testing Accuracy: 0.988281
